# %%
# !pwd
# !ls
# Out:
# /Users/bhaidar/flatiron/dc_ds_04_22_19/module_1/morning_warm_up/week_1
# 1_1_dictionaries.md                Dict_exercise.ipynb
# 1_2_for_loops.md                   ForLoopsAlternatives.ipynb
# 1_3_pandas and numpy.md            Pandas and numpy.ipynb
# 1_4_numpy_func_tr_test_split.md    Untitled.ipynb
# 1_5_visualization_matplotlib.md    plots
# 1_6_simulation_np_random_n_dict.md solutions

# %%
import numpy as np
import pandas as pd

f = pd.read_csv('~/Downloads/co2_mm_mlo.csv', header = None, delim_whitespace=True)

# %%
f
# Out:
#         0   1         2       3       4       5   6
# 0    1958   3  1958.208  315.71  315.71  314.62  -1
# 1    1958   4  1958.292  317.45  317.45  315.29  -1
# 2    1958   5  1958.375  317.50  317.50  314.71  -1
# 3    1958   6  1958.458  -99.99  317.10  314.85  -1
# 4    1958   7  1958.542  315.86  315.86  314.98  -1
# 5    1958   8  1958.625  314.93  314.93  315.94  -1
# 6    1958   9  1958.708  313.20  313.20  315.91  -1
# 7    1958  10  1958.792  -99.99  312.66  315.61  -1
# 8    1958  11  1958.875  313.33  313.33  315.31  -1
# 9    1958  12  1958.958  314.67  314.67  315.61  -1
# 10   1959   1  1959.042  315.62  315.62  315.70  -1
# 11   1959   2  1959.125  316.38  316.38  315.88  -1
# 12   1959   3  1959.208  316.71  316.71  315.62  -1
# 13   1959   4  1959.292  317.72  317.72  315.56  -1
# 14   1959   5  1959.375  318.29  318.29  315.50  -1
# 15   1959   6  1959.458  318.15  318.15  315.92  -1
# 16   1959   7  1959.542  316.54  316.54  315.66  -1
# ...

# %%
f.iloc[:, [0,1,3]].head()
# Out:
#       0  1       3
# 0  1958  3  315.71
# 1  1958  4  317.45
# 2  1958  5  317.50
# 3  1958  6  -99.99
# 4  1958  7  315.86

# %%
count = -1
for i in f.iloc[:,3]:
    count += 1
    if i == -99.99:
        f.iloc[count,3] = np.nan
f
# Out:
#         0   1         2       3       4       5   6
# 0    1958   3  1958.208  315.71  315.71  314.62  -1
# 1    1958   4  1958.292  317.45  317.45  315.29  -1
# 2    1958   5  1958.375  317.50  317.50  314.71  -1
# 3    1958   6  1958.458     NaN  317.10  314.85  -1
# 4    1958   7  1958.542  315.86  315.86  314.98  -1
# 5    1958   8  1958.625  314.93  314.93  315.94  -1
# 6    1958   9  1958.708  313.20  313.20  315.91  -1
# 7    1958  10  1958.792     NaN  312.66  315.61  -1
# 8    1958  11  1958.875  313.33  313.33  315.31  -1
# 9    1958  12  1958.958  314.67  314.67  315.61  -1
# 10   1959   1  1959.042  315.62  315.62  315.70  -1
# 11   1959   2  1959.125  316.38  316.38  315.88  -1
# 12   1959   3  1959.208  316.71  316.71  315.62  -1
# 13   1959   4  1959.292  317.72  317.72  315.56  -1
# 14   1959   5  1959.375  318.29  318.29  315.50  -1
# 15   1959   6  1959.458  318.15  318.15  315.92  -1
# 16   1959   7  1959.542  316.54  316.54  315.66  -1
# ...

# %%
f.columns
new_column_names = ['Year', 'Month', 2, 'CO2', 4, 5, 6]

# %%
f.columns = new_column_names
f.columns
# Out:
# Index(['Year', 'Month', 2, 'CO2', 4, 5, 6], dtype='object')

# %%
f.head()
# Out:
#    Year  Month         2     CO2       4       5  6
# 0  1958      3  1958.208  315.71  315.71  314.62 -1
# 1  1958      4  1958.292  317.45  317.45  315.29 -1
# 2  1958      5  1958.375  317.50  317.50  314.71 -1
# 3  1958      6  1958.458     NaN  317.10  314.85 -1
# 4  1958      7  1958.542  315.86  315.86  314.98 -1

# %%
f['Day'] = 15
f.head()
# Out:
#    Year  Month         2     CO2       4       5  6  Day
# 0  1958      3  1958.208  315.71  315.71  314.62 -1   15
# 1  1958      4  1958.292  317.45  317.45  315.29 -1   15
# 2  1958      5  1958.375  317.50  317.50  314.71 -1   15
# 3  1958      6  1958.458     NaN  317.10  314.85 -1   15
# 4  1958      7  1958.542  315.86  315.86  314.98 -1   15

# %%
from datetime import datetime

# %%
f['Date'] = pd.to_datetime(f[['Year','Month','Day']])
f.head()
# Out:
#    Year  Month         2     CO2       4       5  6  Day       Date
# 0  1958      3  1958.208  315.71  315.71  314.62 -1   15 1958-03-15
# 1  1958      4  1958.292  317.45  317.45  315.29 -1   15 1958-04-15
# 2  1958      5  1958.375  317.50  317.50  314.71 -1   15 1958-05-15
# 3  1958      6  1958.458     NaN  317.10  314.85 -1   15 1958-06-15
# 4  1958      7  1958.542  315.86  315.86  314.98 -1   15 1958-07-15

# %%
f = f.drop('Day', 1)
f.head()
# Out:
#    Year  Month         2     CO2       4       5  6       Date
# 0  1958      3  1958.208  315.71  315.71  314.62 -1 1958-03-15
# 1  1958      4  1958.292  317.45  317.45  315.29 -1 1958-04-15
# 2  1958      5  1958.375  317.50  317.50  314.71 -1 1958-05-15
# 3  1958      6  1958.458     NaN  317.10  314.85 -1 1958-06-15
# 4  1958      7  1958.542  315.86  315.86  314.98 -1 1958-07-15

# %%
f.groupby(['Year']).CO2.mean()
# Out:
# Year
# 1958    315.331250
# 1959    315.974167
# 1960    316.907500
# 1961    317.637500
# 1962    318.450833
# 1963    318.994167
# 1964    319.204444
# 1965    320.044167
# 1966    321.383333
# 1967    322.157500
# 1968    323.045000
# 1969    324.624167
# 1970    325.680000
# 1971    326.320000
# 1972    327.453333
# 1973    329.676667
# 1974    330.185000
# 1975    331.162727
# 1976    332.040000
# 1977    333.831667
# 1978    335.403333
# 1979    336.841667
# 1980    338.751667
# 1981    340.105833
# 1982    341.447500
# 1983    343.054167
# 1984    344.451818
# 1985    346.116667
# 1986    347.420833
# 1987    349.194167
#            ...
# 1990    354.394167
# 1991    355.607500
# 1992    356.445833
# 1993    357.100000
# 1994    358.833333
# 1995    360.820000
# 1996    362.606667
# 1997    363.729167
# 1998    366.700000
# 1999    368.377500
# 2000    369.550000
# 2001    371.142500
# 2002    373.279167
# 2003    375.802500
# 2004    377.522500
# 2005    379.795833
# ...

# %%
f
# Out:
#      Year  Month         2     CO2       4       5   6       Date
# 0    1958      3  1958.208  315.71  315.71  314.62  -1 1958-03-15
# 1    1958      4  1958.292  317.45  317.45  315.29  -1 1958-04-15
# 2    1958      5  1958.375  317.50  317.50  314.71  -1 1958-05-15
# 3    1958      6  1958.458     NaN  317.10  314.85  -1 1958-06-15
# 4    1958      7  1958.542  315.86  315.86  314.98  -1 1958-07-15
# 5    1958      8  1958.625  314.93  314.93  315.94  -1 1958-08-15
# 6    1958      9  1958.708  313.20  313.20  315.91  -1 1958-09-15
# 7    1958     10  1958.792     NaN  312.66  315.61  -1 1958-10-15
# 8    1958     11  1958.875  313.33  313.33  315.31  -1 1958-11-15
# 9    1958     12  1958.958  314.67  314.67  315.61  -1 1958-12-15
# 10   1959      1  1959.042  315.62  315.62  315.70  -1 1959-01-15
# 11   1959      2  1959.125  316.38  316.38  315.88  -1 1959-02-15
# 12   1959      3  1959.208  316.71  316.71  315.62  -1 1959-03-15
# ...

# %%
f.iloc[:,[3,7]].as_matrix()
# Out:
# /Users/bhaidar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# array([[315.71, Timestamp('1958-03-15 00:00:00')],
#        [317.45, Timestamp('1958-04-15 00:00:00')],
#        [317.5, Timestamp('1958-05-15 00:00:00')],
#        ...,
#        [409.07, Timestamp('2018-12-15 00:00:00')],
#        [410.83, Timestamp('2019-01-15 00:00:00')],
#        [411.75, Timestamp('2019-02-15 00:00:00')]], dtype=object)

# %%
count = -1
for i in f.iloc[:,3]:
    count += 1
    if i == -99.99:
        f.iloc[count,3] = np.where
f
# Out:
#      Year  Month         2     CO2       4       5   6       Date
# 0    1958      3  1958.208  315.71  315.71  314.62  -1 1958-03-15
# 1    1958      4  1958.292  317.45  317.45  315.29  -1 1958-04-15
# 2    1958      5  1958.375  317.50  317.50  314.71  -1 1958-05-15
# 3    1958      6  1958.458     NaN  317.10  314.85  -1 1958-06-15
# 4    1958      7  1958.542  315.86  315.86  314.98  -1 1958-07-15
# 5    1958      8  1958.625  314.93  314.93  315.94  -1 1958-08-15
# 6    1958      9  1958.708  313.20  313.20  315.91  -1 1958-09-15
# 7    1958     10  1958.792     NaN  312.66  315.61  -1 1958-10-15
# 8    1958     11  1958.875  313.33  313.33  315.31  -1 1958-11-15
# 9    1958     12  1958.958  314.67  314.67  315.61  -1 1958-12-15
# 10   1959      1  1959.042  315.62  315.62  315.70  -1 1959-01-15
# 11   1959      2  1959.125  316.38  316.38  315.88  -1 1959-02-15
# 12   1959      3  1959.208  316.71  316.71  315.62  -1 1959-03-15
# ...
