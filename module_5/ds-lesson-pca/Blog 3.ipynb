# %%
from pydataset import data

titanic = data('titanic')
# Out:
# initiated datasets repo at: /Users/basselhaidar/.pydataset/

# %%
titanic.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
len(titanic)
# Out:
# 1316

# %%
import pandas as pd

# %%
df = pd.read_csv('/anaconda3/envs/flatiron/lib/python3.7/site-packages/pydataset/resources/rdata/csv/reshape2/tips.csv')
df.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           1       16.99  1.01  Female     No  Sun  Dinner     2
# 1           2       10.34  1.66    Male     No  Sun  Dinner     3
# 2           3       21.01  3.50    Male     No  Sun  Dinner     3
# 3           4       23.68  3.31    Male     No  Sun  Dinner     2
# 4           5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.drop(columns=['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Series are so ugly when you display them
df.tip
# Out:
# 0       1.01
# 1       1.66
# 2       3.50
# 3       3.31
# 4       3.61
# 5       4.71
# 6       2.00
# 7       3.12
# 8       1.96
# 9       3.23
# 10      1.71
# 11      5.00
# 12      1.57
# 13      3.00
# 14      3.02
# 15      3.92
# 16      1.67
# 17      3.71
# 18      3.50
# 19      3.35
# 20      4.08
# 21      2.75
# 22      2.23
# 23      7.58
# 24      3.18
# 25      2.34
# 26      2.00
# 27      2.00
# 28      4.30
# 29      3.00
# 30      1.45
# 31      2.50
# 32      3.00
# 33      2.45
# 34      3.27
# 35      3.60
# 36      2.00
# 37      3.07
# 38      2.31
# 39      5.00
# 40      2.24
# 41      2.54
# 42      3.06
# 43      1.32
# 44      5.60
# 45      3.00
# 46      5.00
# 47      6.00
# 48      2.05
# 49      3.00
# 50      2.50
# 51      2.60
# 52      5.20
# 53      1.56
# 54      4.34
# 55      3.51
# 56      3.00
# 57      1.50
# 58      1.76
# 59      6.73
# 60      3.21
# 61      2.00
# 62      1.98
# 63      3.76
# 64      2.64
# 65      3.15
# ...

# %%
df.tip.dtype
# Out:
# dtype('float64')

# %%
#Operator Precedence df[df.tip > (5.0 & df.sex) == 'Female']

# %%
df[(df.tip > 5.0) & (df.sex == 'Female')]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3

# %%
sorted(df.day)
# Out:
# ['Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Fri',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
#  'Sat',
# ...

# %%
df.day.sort_values()
# Out:
# 96      Fri
# 101     Fri
# 98      Fri
# 97      Fri
# 95      Fri
# 94      Fri
# 93      Fri
# 92      Fri
# 91      Fri
# 90      Fri
# 226     Fri
# 225     Fri
# 224     Fri
# 100     Fri
# 222     Fri
# 221     Fri
# 223     Fri
# 99      Fri
# 220     Fri
# 70      Sat
# 72      Sat
# 73      Sat
# 74      Sat
# 75      Sat
# 76      Sat
# 241     Sat
# 240     Sat
# 234     Sat
# 230     Sat
# 231     Sat
# 232     Sat
# 238     Sat
# 237     Sat
# 233     Sat
# 236     Sat
# 235     Sat
# 229     Sat
# 239     Sat
# 103     Sat
# 69      Sat
# 206     Sat
# 207     Sat
# 208     Sat
# 209     Sat
# 210     Sat
# 211     Sat
# 212     Sat
# 213     Sat
# 214     Sat
# 215     Sat
# 216     Sat
# 217     Sat
# 218     Sat
# 219     Sat
# 242     Sat
# 227     Sat
# 228     Sat
# 111     Sat
# 110     Sat
# 109     Sat
# 108     Sat
# 107     Sat
# 106     Sat
# 105     Sat
# 104     Sat
# 102     Sat
# 68      Sat
# 71      Sat
# 66      Sat
# 39      Sat
# 38      Sat
# ...

# %%
# %%time
df.sort_values(by=['total_bill'])
# Out:
# CPU times: user 736 µs, sys: 52 µs, total: 788 µs
# Wall time: 742 µs
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 195        7.56   1.44    Male     No  Thur   Lunch     2
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2
# 145        8.35   1.50  Female     No  Thur   Lunch     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 126        8.52   1.48    Male     No  Thur   Lunch     2
# 222        8.58   1.92    Male    Yes   Fri   Lunch     1
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 30         9.55   1.45    Male     No   Sat  Dinner     2
# 178        9.60   4.00  Female    Yes   Sun  Dinner     2
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.set_index('sex')
# Out:
#         total_bill    tip smoker   day    time  size
# sex
# Female       16.99   1.01     No   Sun  Dinner     2
# Male         10.34   1.66     No   Sun  Dinner     3
# Male         21.01   3.50     No   Sun  Dinner     3
# Male         23.68   3.31     No   Sun  Dinner     2
# Female       24.59   3.61     No   Sun  Dinner     4
# Male         25.29   4.71     No   Sun  Dinner     4
# Male          8.77   2.00     No   Sun  Dinner     2
# Male         26.88   3.12     No   Sun  Dinner     4
# Male         15.04   1.96     No   Sun  Dinner     2
# Male         14.78   3.23     No   Sun  Dinner     2
# Male         10.27   1.71     No   Sun  Dinner     2
# Female       35.26   5.00     No   Sun  Dinner     4
# Male         15.42   1.57     No   Sun  Dinner     2
# Male         18.43   3.00     No   Sun  Dinner     4
# Female       14.83   3.02     No   Sun  Dinner     2
# Male         21.58   3.92     No   Sun  Dinner     2
# Female       10.33   1.67     No   Sun  Dinner     3
# ...

# %%
df['total_bill'].head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
df.loc[(df['sex'] == 'Male') & (df[day] == 'Sun')]
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 1         10.34   1.66  Male     No   Sun  Dinner     3
# 2         21.01   3.50  Male     No   Sun  Dinner     3
# 3         23.68   3.31  Male     No   Sun  Dinner     2
# 5         25.29   4.71  Male     No   Sun  Dinner     4
# 6          8.77   2.00  Male     No   Sun  Dinner     2
# 7         26.88   3.12  Male     No   Sun  Dinner     4
# 8         15.04   1.96  Male     No   Sun  Dinner     2
# 9         14.78   3.23  Male     No   Sun  Dinner     2
# 10        10.27   1.71  Male     No   Sun  Dinner     2
# 12        15.42   1.57  Male     No   Sun  Dinner     2
# 13        18.43   3.00  Male     No   Sun  Dinner     4
# 15        21.58   3.92  Male     No   Sun  Dinner     2
# 17        16.29   3.71  Male     No   Sun  Dinner     3
# 19        20.65   3.35  Male     No   Sat  Dinner     3
# 20        17.92   4.08  Male     No   Sat  Dinner     2
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# ...

# %%
# %%time
df.sort_values(by=['total_bill'])
# Out:
# CPU times: user 743 µs, sys: 54 µs, total: 797 µs
# Wall time: 750 µs
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 195        7.56   1.44    Male     No  Thur   Lunch     2
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2
# 145        8.35   1.50  Female     No  Thur   Lunch     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 126        8.52   1.48    Male     No  Thur   Lunch     2
# 222        8.58   1.92    Male    Yes   Fri   Lunch     1
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 30         9.55   1.45    Male     No   Sat  Dinner     2
# 178        9.60   4.00  Female    Yes   Sun  Dinner     2
# ...
