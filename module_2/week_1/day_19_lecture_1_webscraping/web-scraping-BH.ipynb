# %% [markdown]
# ![b4s](img/beautiful_soup.png)
#
# ## [Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#beautifulsoup)

# %% [markdown]
# ## Benefits of *not* scraping
# ![options](img/other_options.png)

# %% [markdown]
# ### Use case
#
# ![use](img/use_case.png)

# %% [markdown]
# ### Goal
#
# ![python](img/how_works.png)

# %% [markdown]
# #### Discuss
# What's a website you'd like  to scrape?

# %% [markdown]
# ### Scenario
#
# I want to analyze the top song award of the Grammies to see if I can find any patterns in country of origin, singer, song content, etc.
#
# But where do I start finding that data? Not from an API.
#
# Well, we can start [here](https://en.wikipedia.org/wiki/Grammy_Award_for_Song_of_the_Year)

# %% [markdown]
# ### This is our target
# ![target](img/target.png)

# %% [markdown]
# ### Learning goals:
#
# - scrape a basic wikipedia website using beautiful soup
# - transform the html table we want to a pandas `DataFrame`
# - scrape a more complex wikipedia
# - transform the wanted scraped data into a pandas `DataFrame`
# - if time, go hunt a wild website and scrape it

# %% [markdown]
# ## Basic wikipedia
#
# ![vheck](img/basic.gif)
#
# Task: Get one column from a table on wikipedia

# %% [markdown]
# Let's get those libraries we want

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Use the `url` inside of a `requests.get` and assign it to `website_url`

# %% [markdown]
# First, a wikipedia article where we only want to get one column of information - countries!
#
# https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area').text

# %% [markdown]
# Start to use the BeautifulSoup functions to create a BeautifulSoup object

# %%
soup = BeautifulSoup(website_url,'lxml')
# print(soup.prettify())

# %% [markdown]
# Find the class of interest

# %%
table = soup.find('table',{'class':'wikitable sortable'})

# %% [markdown]
# Keep looking at the html to see if you can find any commonalities in what you want to scrape....

# %% [markdown]
# All the country names are links! We can use the `a` tag!

# %%
links = table.find_all('a')

# %% [markdown]
# We can now iterate over links to process it and create a list of text

# %%
Countries = []
for link in links:
    Countries.append(link.get('title'))
    
print(Countries)
# Out:
# ['Russia', None, 'China', 'Hong Kong', 'Macau', 'India', None, 'Kazakhstan', 'Saudi Arabia', 'Iran', 'Mongolia', 'Indonesia', 'Pakistan', 'Gilgit-Baltistan', 'Azad Kashmir', 'Turkey', 'Myanmar', 'Afghanistan', 'Yemen', 'Thailand', 'Turkmenistan', 'Uzbekistan', 'Iraq', 'Japan', 'Vietnam', 'Malaysia', 'Oman', 'Philippines', 'Laos', 'Kyrgyzstan', 'Syria', 'Golan Heights', 'Cambodia', 'Bangladesh', 'Nepal', 'Tajikistan', 'North Korea', 'South Korea', 'Jordan', 'Azerbaijan', 'United Arab Emirates', 'Georgia (country)', 'Sri Lanka', 'Egypt', 'Bhutan', 'Taiwan', 'Armenia', 'Israel', 'Kuwait', 'East Timor', 'Qatar', 'Lebanon', 'Cyprus', 'Northern Cyprus', 'State of Palestine', 'Brunei', 'Bahrain', 'Singapore', 'Maldives']

# %% [markdown]
# Now, let's convert that list to a data frame

# %%
df = pd.DataFrame()
df['Country'] = Countries

# %%
df.head()
# Out:
#      Country
# 0     Russia
# 1       None
# 2      China
# 3  Hong Kong
# 4      Macau

# %% [markdown]
# ## Less Basic - Get a whole table
# Let's go inspect the webiste to find the right tag/heading/etc for the table we want

# %% [markdown]
# What are the important tags here?<br>
# What class is the important one?

# %% [markdown]
# `table`<br>
# `wikitable sortable`

# %% [markdown]
# **Task**<br>
# Work with a partner to comment the following code and figure out what it does

# %%
response = requests.get('https://en.wikipedia.org/wiki/Grammy_Award_for_Song_of_the_Year').text
#get website url into response

soup = BeautifulSoup(response,'lxml')
#print(soup.prettify())

tab = soup.find("table",{"class":"wikitable sortable"})
# pd.read_html(tab.prettify())

rows = tab.find_all('tr')
# get rows using tr tag 

data = []
for row in rows:
    data.append([x.get_text().strip() for x in row.find_all(['th','td'])])
# append in list data all the rows in the table within th and td tags and strip whitespace

df = pd.DataFrame(data)
# put the data into a pandas dataframe

new_header = df.iloc[0]
# new_header is assigned first row which are the column labels 

df = df[1:]
#fill our dataframe and skip first row since it will be my new_header

df.columns = new_header
# the dataframe columns is assigned the new_header

# %%
df.head()
# Out:
# 0 Year[I]                      Winner(s)            Nationality  \
# 1    1959               Domenico Modugno                  Italy
# 2    1960                Jimmy Driftwood          United States
# 3    1961                    Ernest Gold  United States Austria
# 4    1962     Henry ManciniJohnny Mercer          United States
# 5    1963  Leslie BricusseAnthony Newley         United Kingdom
#
# 0                         Work        Performing artist(s)[II]  \
# 1                   "Volare" *                Domenico Modugno
# 2  "The Battle of New Orleans"                   Johnny Horton
# 3            "Theme of Exodus"  Instrumental (Various Artists)
# 4               "Moon River" *                   Henry Mancini
# 5    "What Kind of Fool Am I?"                 Sammy Davis Jr.
#
# 0                                           Nominees  Ref.
# 1  Paul Vance & Lee Pockriss for "Catch a Falling...  [10]
# 2  Sammy Cahn & Jimmy Van Heusen for "High Hopes"...  [11]
# 3  Charles Randolph Grean, Joe Allison & Audrey A...  [12]
# 4  Jimmy Dean for "Big Bad John" performed by Jim...  [13]
# 5  Lionel Bart for "As Long as He Needs Me" perfo...  [14]

# %% [markdown]
# ### But this is hard. Is there an easier way to do this?

# %% [markdown]
# Another way, if you **know** there is a `table` in the `html` somewhere

# %%
grammies = pd.read_html('https://en.wikipedia.org/wiki/Grammy_Award_for_Song_of_the_Year')

# %% [markdown]
# `grammies` returns a `list` of `DataFrames`<br>
# We still need to find the _correct_ one

# %%
len(grammies)
# Out:
# 5

# %%
grammies[0]
# Out:
#                                    0  \
# 0  Grammy Award for Song of the Year
# 1                        Awarded for
# 2                            Country
# 3                       Presented by
# 4                      First awarded
# 5                  Currently held by
# 6                            Website
#
#                                                    1
# 0                                                NaN
# 1     Quality song containing both lyrics and melody
# 2                                      United States
# 3    National Academy of Recording Arts and Sciences
# 4                                               1959
# 5  Donald Glover, Ludwig Göransson & Jeffery Lama...
# 6                                         grammy.com

# %%
grammies[1]
# Out:
#           0                                                  1  \
# 0   Year[I]                                          Winner(s)
# 1      1959                                   Domenico Modugno
# 2      1960                                    Jimmy Driftwood
# 3      1961                                        Ernest Gold
# 4      1962                         Henry ManciniJohnny Mercer
# 5      1963                      Leslie BricusseAnthony Newley
# 6      1964                         Henry ManciniJohnny Mercer
# 7      1965                                       Jerry Herman
# 8      1966                  Paul Francis WebsterJohnny Mandel
# 9      1967                          John LennonPaul McCartney
# 10     1968                                         Jimmy Webb
# 11     1969                                      Bobby Russell
# 12     1970                                          Joe South
# 13     1971                                         Paul Simon
# 14     1972                                        Carole King
# 15     1973                                       Ewan MacColl
# 16     1974                           Norman GimbelCharles Fox
# 17     1975            Alan and Marilyn BergmanMarvin Hamlisch
# 18     1976                                   Stephen Sondheim
# 19     1977                                     Bruce Johnston
# 20     1978    Barbra StreisandPaul Williams /Joe Brooks (Tie)
# 21     1979                                         Billy Joel
# 22     1980                      Kenny LogginsMichael McDonald
# 23     1981                                  Christopher Cross
# 24     1982                        Donna WeissJackie DeShannon
# 25     1983           Johnny ChristopherMark JamesWayne Carson
# 26     1984                                              Sting
# 27     1985                           Graham LyleTerry Britten
# 28     1986                       Michael JacksonLionel Richie
# 29     1987                   Burt BacharachCarole Bayer Sager
# ..      ...                                                ...
# 32     1990                            Larry HenleyJeff Silbar
# 33     1991                                         Julie Gold
# 34     1992                                      Irving Gordon
# 35     1993                          Eric ClaptonWill Jennings
# 36     1994                                Alan MenkenTim Rice
# 37     1995                                  Bruce Springsteen
# 38     1996                                               Seal
# 39     1997          Gordon KennedyWayne KirkpatrickTommy Sims
# 40     1998                         Shawn ColvinJohn Leventhal
# 41     1999                          James HornerWill Jennings
# 42     2000                               Itaal ShurRob Thomas
# 43     2001  Adam ClaytonDavid EvansLarry Mullen Jr.Paul He...
# 44     2002                                        Alicia Keys
# 45     2003                                       Jesse Harris
# 46     2004                        Richard MarxLuther Vandross
# 47     2005                                         John Mayer
# 48     2006  Adam ClaytonDavid EvansLarry Mullen Jr.Paul He...
# 49     2007  Emily RobisonMartie MaguireNatalie MainesDan W...
# 50     2008                                      Amy Winehouse
# 51     2009  Guy BerrymanJonny BucklandWill ChampionChris M...
# 52     2010  Thaddis HarrellBeyoncé KnowlesTerius NashChris...
# 53     2011   Dave HaywoodJosh KearCharles KelleyHillary Scott
# 54     2012                           Adele AdkinsPaul Epworth
# 55     2013     Nate RuessJack AntonoffJeff BhaskerAndrew Dost
# 56     2014                    Joel LittleElla Yelich-O'Connor
# 57     2015              James NapierWilliam PhillipsSam Smith
# 58     2016                                Ed SheeranAmy Wadge
# 59     2017                           Adele AdkinsGreg Kurstin
# 60     2018  Christopher Brody BrownJames FauntleroyPhilip ...
# 61     2019  Donald GloverLudwig GöranssonJeffery Lamar Wil...
#
#                                2  \
# 0                    Nationality
# 1                          Italy
# 2                  United States
# 3          United States Austria
# 4                  United States
# 5                 United Kingdom
# 6                  United States
# 7                  United States
# 8                  United States
# 9                 United Kingdom
# 10                 United States
# 11                 United States
# 12                 United States
# 13                 United States
# 14                 United States
# 15                United Kingdom
# 16                 United States
# 17                 United States
# 18                 United States
# 19                 United States
# 20                 United States
# 21                 United States
# 22                 United States
# 23                 United States
# 24                 United States
# 25                 United States
# 26                United Kingdom
# 27      United Kingdom Australia
# 28                 United States
# 29                 United States
# ..                           ...
# 32                 United States
# 33                 United States
# 34                 United States
# 35  United Kingdom United States
# 36  United States United Kingdom
# 37                 United States
# 38                United Kingdom
# 39                 United States
# 40                 United States
# 41                 United States
# 42                 United States
# 43                       Ireland
# 44                 United States
# 45                 United States
# 46                 United States
# 47                 United States
# 48                       Ireland
# 49                 United States
# 50                United Kingdom
# 51                United Kingdom
# 52                 United States
# 53                 United States
# 54                United Kingdom
# 55                 United States
# 56                   New Zealand
# 57                United Kingdom
# 58                United Kingdom
# 59  United Kingdom United States
# 60                 United States
# 61          United States Sweden
#
#                                                     3  \
# 0                                                Work
# 1                                          "Volare" *
# 2                         "The Battle of New Orleans"
# 3                                   "Theme of Exodus"
# 4                                      "Moon River" *
# 5                           "What Kind of Fool Am I?"
# 6                          "Days of Wine and Roses" *
# 7                                     "Hello, Dolly!"
# 8                          "The Shadow of Your Smile"
# 9                                          "Michelle"
# 10                               "Up, Up, and Away" *
# 11                              "Little Green Apples"
# 12                                "Games People Play"
# 13                     "Bridge over Troubled Water" *
# 14                              "You've Got a Friend"
# 15            "The First Time Ever I Saw Your Face" *
# 16                "Killing Me Softly with His Song" *
# 17                                  "The Way We Were"
# 18                               "Send in the Clowns"
# 19                                "I Write the Songs"
# 20  "Evergreen (Love Theme from A Star Is Born)" /...
# 21                           "Just the Way You Are" *
# 22                           "What a Fool Believes" *
# 23                                        "Sailing" *
# 24                               "Bette Davis Eyes" *
# 25                                "Always on My Mind"
# 26                            "Every Breath You Take"
# 27                  "What's Love Got to Do with It" *
# 28                               "We Are the World" *
# 29                      "That's What Friends Are For"
# ..                                                ...
# 32                          "Wind Beneath My Wings" *
# 33                                  "From a Distance"
# 34                                  "Unforgettable" *
# 35                                "Tears in Heaven" *
# 36                                "A Whole New World"
# 37                          "Streets of Philadelphia"
# 38                               "Kiss from a Rose" *
# 39                               "Change the World" *
# 40                                "Sunny Came Home" *
# 41                            "My Heart Will Go On" *
# 42                                         "Smooth" *
# 43                                  "Beautiful Day" *
# 44                                          "Fallin'"
# 45                                 "Don't Know Why" *
# 46                             "Dance with My Father"
# 47                                        "Daughters"
# 48          "Sometimes You Can't Make It on Your Own"
# 49                         "Not Ready to Make Nice" *
# 50                                          "Rehab" *
# 51                                     "Viva la Vida"
# 52                 "Single Ladies (Put a Ring on It)"
# 53                                   "Need You Now" *
# 54                            "Rolling in the Deep" *
# 55                                     "We Are Young"
# 56                                           "Royals"
# 57               "Stay with Me" (Darkchild version) *
# 58                                "Thinking Out Loud"
# 59                                          "Hello" *
# 60                               "That's What I Like"
# 61                                "This Is America" *
#
#                                                     4  \
# 0                            Performing artist(s)[II]
# 1                                    Domenico Modugno
# 2                                       Johnny Horton
# 3                      Instrumental (Various Artists)
# 4                                       Henry Mancini
# 5                                     Sammy Davis Jr.
# 6                                       Henry Mancini
# 7                                     Louis Armstrong
# 8                                        Tony Bennett
# 9                                         The Beatles
# 10                                  The 5th Dimension
# 11                                        O. C. Smith
# 12                                          Joe South
# 13                                  Simon & Garfunkel
# 14                         James Taylor & Carole King
# 15                                      Roberta Flack
# 16                                      Roberta Flack
# 17                                   Barbra Streisand
# 18                                       Judy Collins
# 19                                      Barry Manilow
# 20                      Barbra Streisand /Debby Boone
# 21                                         Billy Joel
# 22                                The Doobie Brothers
# 23                                  Christopher Cross
# 24                                         Kim Carnes
# 25                                      Willie Nelson
# 26                                         The Police
# 27                                        Tina Turner
# 28                                     USA for Africa
# 29  Dionne Warwick & Friends (Elton John, Gladys K...
# ..                                                ...
# 32                                       Bette Midler
# 33                                       Bette Midler
# 34                    Natalie Cole with Nat King Cole
# 35                                       Eric Clapton
# 36                        Peabo Bryson & Regina Belle
# 37                                  Bruce Springsteen
# 38                                               Seal
# 39                                       Eric Clapton
# 40                                       Shawn Colvin
# 41                                        Celine Dion
# 42                       Santana featuring Rob Thomas
# 43                                                 U2
# 44                                        Alicia Keys
# 45                                        Norah Jones
# 46                                    Luther Vandross
# 47                                         John Mayer
# 48                                                 U2
# 49                                       Dixie Chicks
# 50                                      Amy Winehouse
# 51                                           Coldplay
# 52                                            Beyoncé
# 53                                    Lady Antebellum
# 54                                              Adele
# 55                        Fun featuring Janelle Monáe
# 56                                              Lorde
# 57                                          Sam Smith
# 58                                         Ed Sheeran
# 59                                              Adele
# 60                                         Bruno Mars
# 61                                   Childish Gambino
#
#                                                     5         6
# 0                                            Nominees      Ref.
# 1   Paul Vance & Lee Pockriss for "Catch a Falling...      [10]
# 2   Sammy Cahn & Jimmy Van Heusen for "High Hopes"...      [11]
# 3   Charles Randolph Grean, Joe Allison & Audrey A...      [12]
# 4   Jimmy Dean for "Big Bad John" performed by Jim...      [13]
# 5   Lionel Bart for "As Long as He Needs Me" perfo...      [14]
# 6   Sammy Cahn & Jimmy Van Heusen for "Call Me Irr...      [15]
# 7   John Lennon & Paul McCartney for "A Hard Day's...      [16]
# 8   Michel Legrand, Norman Gimbel & Jacques Demy f...       NaN
# 9   John Barry & Don Black for "Born Free" perform...       NaN
# 10  Jimmy Webb for "By the Time I Get to Phoenix" ...      [17]
# 11  Tom T. Hall for "Harper Valley PTA" performed ...      [18]
# 12  Larry Kusik, Eddie Snyder & Nino Rota for "A T...      [19]
# 13  Ray Stevens for "Everything Is Beautiful" perf...      [20]
# 14  Kris Kristofferson for "Help Me Make It Throug...      [21]
# 15  Gilbert O'Sullivan for "Alone Again (Naturally...      [22]
# 16  Kenny O'Dell for "Behind Closed Doors" perform...      [23]
# 17  Gene McDaniels for "Feel Like Makin' Love" per...       NaN
# 18  Janis Ian for "At Seventeen" performed by Jani...      [24]
# 19  Bill Danoff for "Afternoon Delight" performed ...      [25]
# 20  Richard Leigh for "Don't It Make My Brown Eyes...      [26]
# 21  Barry Gibb, Robin Gibb & Maurice Gibb for "Sta...      [27]
# 22  David Foster, Jay Graydon & Bill Champlin for ...      [28]
# 23  Michael Gore & Dean Pitchford for "Fame" perfo...      [29]
# 24  Peter Allen, Burt Bacharach, Carole Bayer Sage...      [30]
# 25  Paul McCartney for "Ebony and Ivory" performed...      [31]
# 26  Lionel Richie for "All Night Long (All Night)"...       NaN
# 27  Phil Collins for "Against All Odds (Take a Loo...      [32]
# 28  Mark Knopfler & Sting for "Money for Nothing" ...      [33]
# 29  Peter Gabriel for "Sledgehammer" performed by ...      [34]
# ..                                                ...       ...
# 32  Barry Mann, Cynthia Weil & Tom Snow for "Don't...      [37]
# 33  Mariah Carey & Ben Margulies for "Vision of Lo...      [38]
# 34  Bryan Adams, Robert Lange & Michael Kamen for ...      [39]
# 35  Don Von Tress for "Achy Breaky Heart" performe...      [40]
# 36  Billy Joel for "The River of Dreams" performed...      [41]
# 37  David Baerwald, Bill Bottrell, Wyn Cooper, She...      [42]
# 38  Eric Bazilian for "One of Us" performed by Joa...      [43]
# 39  Tracy Chapman for "Give Me One Reason" perform...      [44]
# 40  Eric Stefani & Gwen Stefani for "Don't Speak" ...      [45]
# 41  Diane Warren for "I Don't Want to Miss a Thing...      [46]
# 42  Andreas Carlsson & Max Martin for "I Want It T...      [47]
# 43  Beyoncé Knowles, Rodney Jerkins, LaShawn Danie...      [48]
# 44  India.Arie, Carlos "Six July" Broady & Shannon...      [49]
# 45  Vanessa Carlton for "A Thousand Miles" perform...      [50]
# 46  Linda Perry for "Beautiful" performed by Chris...      [51]
# 47  Alicia Keys for "If I Ain't Got You" performed...      [52]
# 48  Johntá Austin, Babyface, Mariah Carey, Jermain...      [53]
# 49  Johnta Austin, Mary J. Blige, Bryan-Michael Co...      [54]
# 50  Josh Kear & Chris Tompkins for "Before He Chea...      [55]
# 51  Estelle, Keith Harris, John Legend, Josh Lopez...      [56]
# 52  Lady Gaga & RedOne for "Poker Face" performed ...      [57]
# 53  Ray LaMontagne for "Beg Steal Or Borrow" perfo...      [58]
# 54  Jeff Bhasker, Stacy Ferguson, Malik Jones, War...      [59]
# 55  Ed Sheeran for "The A Team" performed by Ed Sh...      [60]
# 56  Jeff Bhasker, Pink & Nate Ruess for "Just Give...      [61]
# 57  Andrew Hozier-Byrne for "Take Me to Church" pe...      [62]
# 58  Kendrick Duckworth, Mark Anthony Spears & Phar...      [63]
# 59  Khalif Brown, Asheton Hogan, Beyoncé Knowles &...      [64]
# 60  Ramón Ayala Rodríguez, Justin Bieber, Jason Bo...      [65]
# 61  Kendrick Duckworth, Solána Rowe, Al Shuckburg,...  [66][67]
#
# [62 rows x 7 columns]

# %%
grammies[2]
# Out:
#                                       0  \
# 0  vteGrammy Award for Song of the Year
# 1                             1959−1980
# 2                             1981−2000
# 3                          2001−present
#
#                                                    1
# 0                                                NaN
# 1  "Volare" – Domenico Modugno (songwriter) (1959...
# 2  "Sailing" – Christopher Cross (songwriter) (19...
# 3  "Beautiful Day" – Adam Clayton, David Evans, L...

# %%
grammies[3]
# Out:
#                                                    0  \
# 0                                    vteGrammy Award
# 1  Categories Grammy Nominees Records Locations EGOT
# 2                                     Special awards
# 3                                      Ceremony year
# 4                                            Related
# 5                                         By Country
# 6  Grammy Award Record of the Year Song of the Ye...
#
#                                                    1
# 0                                                NaN
# 1                                                NaN
# 2  Legend Award Lifetime Achievement Award Truste...
# 3  1959 May Nov 1961 1962 1963 1964 1965 1966 196...
# 4                                      Grammy Museum
# 5  American Argentine Australian Austrian Brazili...
# 6                                                NaN

# %%
grammies[4]
# Out:
#                                        0  \
# 0             vteGrammy Award categories
# 1                                General
# 2                                    Pop
# 3                       Dance/Electronic
# 4                                   Rock
# 5                            Alternative
# 6                                    R&B
# 7                            Rap/Hip-Hop
# 8                                Country
# 9                                   Jazz
# 10  Gospel/ Contemporary Christian Music
# 11                                 Latin
# 12                        American Roots
# 13                Music for Visual Media
# 14                   Composing/Arranging
# 15                                Crafts
# 16                Production/Engineering
# 17                             Classical
# 18                           Music Video
# 19                                Others
# 20                        Special Awards
#
#                                                     1
# 0                                                 NaN
# 1   Record of the Year Album of the Year Song of t...
# 2   Best Pop Solo Performance Best Pop Duo/Group P...
# 3    Best Dance Recording Best Dance/Electronic Album
# 4   Best Rock Performance Best Metal Performance B...
# 5                        Best Alternative Music Album
# 6   Best R&B Performance Best Traditional R&B Perf...
# 7   Best Rap Performance Best Rap/Sung Performance...
# 8   Best Country Solo Performance Best Country Duo...
# 9   Best Improvised Jazz Solo Best Jazz Vocal Albu...
# 10  Best Gospel Performance/Song Best Gospel Album...
# 11  Best Latin Pop Album Best Latin Rock, Urban or...
# 12  Best Americana Album Best Bluegrass Album Best...
# 13  Best Compilation Soundtrack for Visual Media B...
# 14  Best Instrumental Composition Best Arrangement...
# 15  Best Historical Album Best Recording Package B...
# 16  Best Engineered Album, Non-Classical Best Engi...
# 17  Best Orchestral Performance Best Opera Recordi...
# 18                   Best Music Video Best Music Film
# 19  Contemporary Instrumental Best Contemporary In...
# 20  Lifetime Achievement Award Trustees Award Lege...

# %% [markdown]
# Another way with the same concept....

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_American_Grammy_Award_winners_and_nominees')
soup = BeautifulSoup(response.text)

tab = soup.find("table",{"class":"wikitable sortable"})
df = pd.read_html(tab.prettify())
# Out:
# /Users/bhaidar/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/bhaidar/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
df
# Out:
# [                                                     0     1            2
#  0                                              Nominee  Wins  Nominations
#  1                                    Quincy Jones  [1]    28           80
#  2                                   Alison Krauss  [2]    27           42
#  3                                   Stevie Wonder  [3]    25           74
#  4                               Vladimir Horowitz  [4]    25           45
#  5                                   John Williams  [5]    24           69
#  6                                         Beyoncé  [6]    23           66
#  7                                           Jay-Z  [7]    22           77
#  8                                     Chick Corea  [8]    22           64
#  9                                      Kanye West  [9]    21           69
#  10                                    Vince Gill  [10]    21           45
#  11                                 Henry Mancini  [11]    20           72
#  12                             Bruce Springsteen  [12]    20           50
#  13                 Pat Metheny  [13]  Al Schmitt  [14]    20           36
#  14                               Aretha Franklin  [15]    18           44
#  15                                  Tony Bennett  [16]    18           36
#  16                                      Yo-Yo Ma  [17]    18           27
#  17                                   Jimmy Sturr  [18]    18           24
#  18                                   Ray Charles  [19]    17           37
#  19                             Leonard Bernstein  [20]    16           63
#  20                               James Mallinson  [21]    16           49
#  21                                    Paul Simon  [22]    16           35
#  22                                   David Frost  [23]    16           21
#  23                                        Eminem  [24]    15           44
#  24                                Steven Epstein  [25]    15           35
#  25                                   Alicia Keys  [26]    15           29
#  26                                    Bela Fleck  [27]    14           33
#  27                                   Phil Ramone  [28]    14           32
#  28               Alison Krauss and Union Station  [29]    14           18
#  29                                Jay David Saks  [30]    13           53
#  ..                                                 ...   ...          ...
#  130       Lin-Manuel Miranda  [155]  Tim Martyn  [156]     3            4
#  131                                 Lenny White  [157]     3            3
#  132                      Cyndi Lauper  Miranda Lambert     2           16
#  133                                  Melissa Etheridge     2           15
#  134                                      Patti LaBelle     2           13
#  135                                        Marvin Gaye     2           12
#  136                                     Yehudi Menuhin     2           10
#  137    Intocable  No Doubt  Jimmy Carter  Brian Wilson     2            9
#  138               Marc Anthony  Peter Nero  Nate Ruess     2            8
#  139  La Mafia  LeAnn Rimes  Brave Combo  Fleetwood Mac     2            7
#  140          Jennifer Hudson  Linkin Park  Andrew Dost     2            6
#  141  Nate Hills  Otis Redding  Bobby Darin  Vernon ...     2            5
#  142    Ted Nash (saxophonist, born 1960)  The Wreckers     2            4
#  143  Little Joe y La Familia  Lisa Fischer  St. Vin...     2            3
#  144                             Judy Garland  Dua Lipa     2            2
#  145                                        Chris Brown     1           16
#  146                            50 Cent  Elvis Costello     1           14
#  147                                       Ray Barretto     1           13
#  148         Pearl Jam  Carter Beauford  Brandy Norwood     1           12
#  149  Dave Matthews Band  Eddie Blazonczyk  Jon Bon ...     1           11
#  150                              Q-Tip  Chicago (band)     1           10
#  151               David Crosby  The Neptunes  Bon Jovi     1            9
#  152  Ashanti  Britney Spears  Mariachi Divas  John ...     1            8
#  153  Cher  Cardi B  Queen Latifah  Mongo Santamaria...     1            7
#  154  Stargate  Bobby Bare  Crosby, Stills & Nash  A...     1            6
#  155  Gloria Gaynor  Emilio Navaira  Ciara  Fun (ban...     1            5
#  156  Enrique Iglesias  The Chainsmokers  Steve Jord...     1            4
#  157  Cal Tjader  Mariachi los Camperos  Texas Torna...     1            3
#  158  Gloria Cheng  Bacilos  Los Super Seven  The Le...     1            2
#  159  Jesse Harris  Sirah (rapper)  Solange  Stephen...     1            1
#
#  [160 rows x 3 columns]]

# %% [markdown]
# ## Now find a free-range website
#
# get in groups of four and try to scrape a website into a pandas df

# %%
another_website_url = requests.get('https://www.pro-football-reference.com/teams/nwe/2018.htm').text

# %%
another_soup = BeautifulSoup(another_website_url)
# Out:
# /Users/bhaidar/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/bhaidar/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# print(another_soup.prettify())

# %%
another_table = another_soup.find_all('table',{'class':'sortable'})

# %%
data_row = another_table[1].find_all('tr')

# %%
# tab = soup.find("table",{"class":"wikitable sortable"})
# pd.read_html(tab.prettify())

# rows = tab.find_all('tr')
# get rows using tr tag 

data = []
for row in data_row:
    data.append([x.get_text().strip() for x in row.find_all(['th','td'])])
# append in list data all the rows in the table within th and td tags and strip whitespace

df = pd.DataFrame(data)
# put the data into a pandas dataframe

# %%
df
# Out:
#               0      1             2          3                4     5     6   \
# 0                 Score       Offense    Defense  Expected Points  None  None
# 1           Week    Day          Date                                      OT
# 2              1    Sun   September 9  1:00PM ET         boxscore     W
# 3              2    Sun  September 16  4:25PM ET         boxscore     L
# 4              3    Sun  September 23  8:20PM ET         boxscore     L
# 5              4    Sun  September 30  1:00PM ET         boxscore     W
# 6              5    Thu     October 4  8:20PM ET         boxscore     W
# 7              6    Sun    October 14  8:20PM ET         boxscore     W
# 8              7    Sun    October 21  1:00PM ET         boxscore     W
# 9              8    Mon    October 29  8:15PM ET         boxscore     W
# 10             9    Sun    November 4  8:20PM ET         boxscore     W
# 11            10    Sun   November 11  1:00PM ET         boxscore     L
# 12            11
# 13            12    Sun   November 25  1:00PM ET         boxscore     W
# 14            13    Sun    December 2  4:25PM ET         boxscore     W
# 15            14    Sun    December 9  1:00PM ET         boxscore     L
# 16            15    Sun   December 16  4:25PM ET         boxscore     L
# 17            16    Sun   December 23  1:00PM ET         boxscore     W
# 18            17    Sun   December 30  1:00PM ET         boxscore     W
# 19                           Playoffs
# 20      Division    Sun    January 13  1:05PM ET         boxscore     W
# 21  Conf. Champ.    Sun    January 20  6:40PM ET         boxscore     W    OT
# 22     SuperBowl    Sun    February 3  6:30PM ET         boxscore     W
#
#       7     8                     9    ...        15    16    17     18  \
# 0   None  None                  None   ...      None  None  None   None
# 1    Rec                         Opp   ...     RushY    TO  1stD  TotYd
# 2    1-0              Houston Texans   ...       122     3    21    325
# 3    1-1     @  Jacksonville Jaguars   ...        82     1    27    480
# 4    1-2     @         Detroit Lions   ...        89     1    25    414
# 5    2-2              Miami Dolphins   ...       175     2    11    172
# 6    3-2          Indianapolis Colts   ...        97     2    26    439
# 7    4-2          Kansas City Chiefs   ...       173     1    18    446
# 8    5-2     @         Chicago Bears   ...       108     3    29    453
# 9    6-2     @         Buffalo Bills   ...        76          16    333
# 10   7-2           Green Bay Packers   ...       123          22    367
# 11   7-3     @      Tennessee Titans   ...        40          23    385
# 12                          Bye Week   ...
# 13   8-3     @         New York Jets   ...       215          18    338
# 14   9-3           Minnesota Vikings   ...       160     1    16    278
# 15   9-4     @        Miami Dolphins   ...        77          20    412
# 16   9-5     @   Pittsburgh Steelers   ...        96     1    24    376
# 17  10-5               Buffalo Bills   ...       273     3    14    289
# 18  11-5               New York Jets   ...       131          12    239
# 19                                     ...
# 20  12-5        Los Angeles Chargers   ...       155          22    335
# 21  13-5     @    Kansas City Chiefs   ...       176     2    18    290
# 22  14-5     N      Los Angeles Rams   ...       154     1    14    260
#
#        19     20    21       22       23       24
# 0    None   None  None     None     None     None
# 1   PassY  RushY    TO  Offense  Defense  Sp. Tms
# 2     158    167     2     4.29     8.05    -6.85
# 3     376    104     2     2.13   -18.76     4.44
# 4     255    159     1    -5.39   -13.69     2.81
# 5     116     56     2    21.22    12.47    -5.93
# 6     355     84     3    13.90    -2.15     2.13
# 7     352     94     2    21.54   -10.83    -8.17
# 8     319    134     2     9.37   -16.89     5.95
# 9     287     46     2     3.65    20.98    -6.85
# 10    250    117     1    17.14    -4.92     3.52
# 11    235    150          -5.76   -14.31    -2.47
# 12
# 13    264     74     1    20.12    -2.42    -4.96
# 14    183     95     2    17.05     9.14    -5.11
# 15    223    189          20.29   -20.06     0.60
# 16    218    158     2     1.22   -10.75     3.62
# 17    217     72     3    -6.39    16.90     2.11
# 18    135    104     3    12.41    29.00    -5.46
# 19
# 20    316     19     2    23.29   -11.48     4.94
# 21    249     41          18.42   -15.09     2.27
# 22    198     62     1     2.46    12.15    -4.67
#
# [23 rows x 25 columns]

# %%
new_header = df.iloc[0]
# new_header is assigned first row which are the column labels 

df = df[1:]
#fill our dataframe and skip first row since it will be my new_header

df.columns = new_header
# the dataframe columns is assigned the new_header

# %%
df
# Out:
# 2              1  Sun   September 9  1:00PM ET  boxscore  W       1-0     \
# 4              3  Sun  September 23  8:20PM ET  boxscore  L       1-2  @
# 5              4  Sun  September 30  1:00PM ET  boxscore  W       2-2
# 6              5  Thu     October 4  8:20PM ET  boxscore  W       3-2
# 7              6  Sun    October 14  8:20PM ET  boxscore  W       4-2
# 8              7  Sun    October 21  1:00PM ET  boxscore  W       5-2  @
# 9              8  Mon    October 29  8:15PM ET  boxscore  W       6-2  @
# 10             9  Sun    November 4  8:20PM ET  boxscore  W       7-2
# 11            10  Sun   November 11  1:00PM ET  boxscore  L       7-3  @
# 12            11
# 13            12  Sun   November 25  1:00PM ET  boxscore  W       8-3  @
# 14            13  Sun    December 2  4:25PM ET  boxscore  W       9-3
# 15            14  Sun    December 9  1:00PM ET  boxscore  L       9-4  @
# 16            15  Sun   December 16  4:25PM ET  boxscore  L       9-5  @
# 17            16  Sun   December 23  1:00PM ET  boxscore  W      10-5
# 18            17  Sun   December 30  1:00PM ET  boxscore  W      11-5
# 19                         Playoffs
# 20      Division  Sun    January 13  1:05PM ET  boxscore  W      12-5
# 21  Conf. Champ.  Sun    January 20  6:40PM ET  boxscore  W  OT  13-5  @
# 22     SuperBowl  Sun    February 3  6:30PM ET  boxscore  W      14-5  N
#
# 2         Houston Texans  ...    122  3  21  325  158  167  2   4.29    8.05  \
# 4          Detroit Lions  ...     89  1  25  414  255  159  1  -5.39  -13.69
# 5         Miami Dolphins  ...    175  2  11  172  116   56  2  21.22   12.47
# 6     Indianapolis Colts  ...     97  2  26  439  355   84  3  13.90   -2.15
# 7     Kansas City Chiefs  ...    173  1  18  446  352   94  2  21.54  -10.83
# 8          Chicago Bears  ...    108  3  29  453  319  134  2   9.37  -16.89
# 9          Buffalo Bills  ...     76     16  333  287   46  2   3.65   20.98
# 10     Green Bay Packers  ...    123     22  367  250  117  1  17.14   -4.92
# 11      Tennessee Titans  ...     40     23  385  235  150     -5.76  -14.31
# 12              Bye Week  ...
# 13         New York Jets  ...    215     18  338  264   74  1  20.12   -2.42
# 14     Minnesota Vikings  ...    160  1  16  278  183   95  2  17.05    9.14
# 15        Miami Dolphins  ...     77     20  412  223  189     20.29  -20.06
# 16   Pittsburgh Steelers  ...     96  1  24  376  218  158  2   1.22  -10.75
# 17         Buffalo Bills  ...    273  3  14  289  217   72  3  -6.39   16.90
# 18         New York Jets  ...    131     12  239  135  104  3  12.41   29.00
# 19                        ...
# 20  Los Angeles Chargers  ...    155     22  335  316   19  2  23.29  -11.48
# 21    Kansas City Chiefs  ...    176  2  18  290  249   41     18.42  -15.09
# 22      Los Angeles Rams  ...    154  1  14  260  198   62  1   2.46   12.15
#
# 2   -6.85
# 4    2.81
# 5   -5.93
# 6    2.13
# 7   -8.17
# 8    5.95
# 9   -6.85
# 10   3.52
# 11  -2.47
# 12
# 13  -4.96
# 14  -5.11
# 15   0.60
# 16   3.62
# 17   2.11
# 18  -5.46
# 19
# 20   4.94
# 21   2.27
# 22  -4.67
#
# [19 rows x 25 columns]
