# %% [markdown]
# # Object Oriented Programing - Part 1
# ## Or why a data scientist should care about classes

# %% [markdown]
# ## Scenario
#
# You want to build an automated datascience pipeline to monitor and predict stock performance.
# What would you do?
#
# ![stocks](img/stocks.jpeg)

# %% [markdown]
# While we won't complete this today, in order to build that you'd need to:
#
# - describe the limits of custom functions
# - identify and paraphrase the vocabulary of Object Oriented Programming
# - build a new small sample class
# - map out the blueprint of a class for the stock monitoring data science pipeline

# %% [markdown]
# ### Let's start with the familiar: functions, why do we care about them?

# %% [markdown]
# But, how is a function like a pipe?

# %% [markdown]
# ![pipes](img/funtions-pipe.jpeg)

# %% [markdown]
# **What if** there was a way to bundle your input data, output data, and a bunch of functions _all together_ in a repeatable fashion?

# %% [markdown]
# Well, _**there is**_.

# %% [markdown]
# Or to put it differently:

# %% [markdown]
# #### HI BILLY MAYS HERE

# %% [markdown]
# ![mayes](img/mayes.png)

# %% [markdown]
# #### Example 1
# When we use `type()` what are we checking?
#
# ```
# example = ["one", "two", 3]
# type(example)
# type(example[-1])
# ```

# %% [markdown]
# `example` is an _object_ of _class type_ **list**

# %% [markdown]
# What can we know about `example` now that we know it is a **list** ?

# %% [markdown]
# #### Example 2
#
# ```
# import pandas as pd
#
# sampledf = pd.Dataframe()
#
# ```

# %%
import pandas as pd

sampledf = pd.DataFrame()

# %% [markdown]
# When we create an "object", using the blue-print of a _class_, even when it is **empty** that is called _initializing_ the object.

# %% [markdown]
# Even though it is empty, it is still an _object_ of _class_ pandas DataFrame.

# %%
type(sampledf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# What do we know we can ask about this object?
# What are its _attributes_ ?

# %%
sampledf.columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# What about _methods_ ? What methods are available for data frames?

# %%
sampledf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame

# %% [markdown]
# What other attributes and methods can you use on a dataframe? Try them on `sampledf`<br>
# The methods and attributes for dataframes are found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %% [markdown]
# **Task**: Try working with the methods and attributes of data frames on the `airports.csv` dataset

# %%
sampledf.T
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sampledf.size
# Out:
# 0

# %%
airports = pd.read_csv('airports.csv')

# %%
airports.columns
# Out:
# Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')

# %%
airports.shape
# Out:
# (322, 7)

# %%
airports.dtypes
# Out:
# IATA_CODE     object
# AIRPORT       object
# CITY          object
# STATE         object
# COUNTRY       object
# LATITUDE     float64
# LONGITUDE    float64
# dtype: object

# %%
airports.values
# Out:
# array([['ABE', 'Lehigh Valley International Airport', 'Allentown', ...,
#         'USA', 40.652359999999994, -75.4404],
#        ['ABI', 'Abilene Regional Airport', 'Abilene', ..., 'USA',
#         32.41132, -99.6819],
#        ['ABQ', 'Albuquerque International Sunport', 'Albuquerque', ...,
#         'USA', 35.04022, -106.60918999999998],
#        ...,
#        ['XNA', 'Northwest Arkansas Regional Airport',
#         'Fayetteville/Springdale/Rogers', ..., 'USA', 36.28187,
#         -94.30681],
#        ['YAK', 'Yakutat Airport', 'Yakutat', ..., 'USA', 59.50336,
#         -139.66023],
#        ['YUM', 'Yuma International Airport', 'Yuma', ..., 'USA',
#         32.65658, -114.60597]], dtype=object)

# %%
airports.is_copy
# Out:
# /Users/bhaidar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   """Entry point for launching an IPython kernel.

# %%
airports.all()
# Out:
# IATA_CODE    True
# AIRPORT      True
# CITY         True
# STATE        True
# COUNTRY      True
# LATITUDE     True
# LONGITUDE    True
# dtype: bool

# %%
airports.clip()
# Out:
#     IATA_CODE                                            AIRPORT  \
# 0         ABE                Lehigh Valley International Airport
# 1         ABI                           Abilene Regional Airport
# 2         ABQ                  Albuquerque International Sunport
# 3         ABR                          Aberdeen Regional Airport
# 4         ABY                 Southwest Georgia Regional Airport
# 5         ACK                         Nantucket Memorial Airport
# 6         ACT                              Waco Regional Airport
# 7         ACV                                     Arcata Airport
# 8         ACY                Atlantic City International Airport
# 9         ADK                                       Adak Airport
# 10        ADQ                                     Kodiak Airport
# 11        AEX                   Alexandria International Airport
# 12        AGS              Augusta Regional Airport (Bush Field)
# 13        AKN                                King Salmon Airport
# 14        ALB                       Albany International Airport
# 15        ALO                          Waterloo Regional Airport
# 16        AMA        Rick Husband Amarillo International Airport
# 17        ANC        Ted Stevens Anchorage International Airport
# 18        APN                     Alpena County Regional Airport
# 19        ASE                        Aspen-Pitkin County Airport
# 20        ATL   Hartsfield-Jackson Atlanta International Airport
# 21        ATW                     Appleton International Airport
# 22        AUS             Austin-Bergstrom International Airport
# 23        AVL                         Asheville Regional Airport
# 24        AVP        Wilkes-Barre/Scranton International Airport
# 25        AZO       Kalamazoo/Battle Creek International Airport
# 26        BDL                      Bradley International Airport
# 27        BET                                     Bethel Airport
# 28        BFL                                      Meadows Field
# 29        BGM                         Greater Binghamton Airport
# ..        ...                                                ...
# 292       SRQ           Sarasota-Bradenton International Airport
# 293       STC                         St. Cloud Regional Airport
# 294       STL   St. Louis International Airport at Lambert Field
# 295       STT                              Cyril E. King Airport
# 296       STX                           Henry E. Rohlsen Airport
# 297       SUN                          Friedman Memorial Airport
# 298       SUX                              Sioux Gateway Airport
# 299       SWF                      Stewart International Airport
# 300       SYR             Syracuse Hancock International Airport
# 301       TLH                  Tallahassee International Airport
# 302       TOL                             Toledo Express Airport
# 303       TPA                        Tampa International Airport
# 304       TRI                        Tri-Cities Regional Airport
# 305       TTN                             Trenton Mercer Airport
# 306       TUL                        Tulsa International Airport
# 307       TUS                       Tucson International Airport
# 308       TVC                             Cherry Capital Airport
# 309       TWF       Magic Valley Regional Airport (Joslin Field)
# 310       TXK            Texarkana Regional Airport (Webb Field)
# 311       TYR                      Tyler Pounds Regional Airport
# 312       TYS                               McGhee Tyson Airport
# 313       UST  Northeast Florida Regional Airport (St. August...
# 314       VEL                                     Valdez Airport
# 315       VLD                          Valdosta Regional Airport
# 316       VPS         Destin-Fort Walton Beach Airport/Eglin AFB
# 317       WRG                                   Wrangell Airport
# 318       WYS                             Westerly State Airport
# 319       XNA                Northwest Arkansas Regional Airport
# 320       YAK                                    Yakutat Airport
# 321       YUM                         Yuma International Airport
#
#                                CITY STATE COUNTRY LATITUDE LONGITUDE
# 0                         Allentown    PA     USA  40.6524  -75.4404
# 1                           Abilene    TX     USA  32.4113  -99.6819
# 2                       Albuquerque    NM     USA  35.0402  -106.609
# 3                          Aberdeen    SD     USA  45.4491  -98.4218
# 4                            Albany    GA     USA  31.5355  -84.1945
# 5                         Nantucket    MA     USA  41.2531  -70.0602
# 6                              Waco    TX     USA  31.6113  -97.2305
# 7                     Arcata/Eureka    CA     USA  40.9781  -124.109
# 8                     Atlantic City    NJ     USA  39.4576  -74.5772
# 9                              Adak    AK     USA   51.878  -176.646
# 10                           Kodiak    AK     USA    57.75  -152.494
# 11                       Alexandria    LA     USA  31.3274  -92.5486
# 12                          Augusta    GA     USA    33.37  -81.9645
# 13                      King Salmon    AK     USA  58.6768  -156.649
# 14                           Albany    NY     USA  42.7481   -73.803
# 15                         Waterloo    IA     USA  42.5571  -92.4003
# 16                         Amarillo    TX     USA  35.2194  -101.706
# 17                        Anchorage    AK     USA  61.1743  -149.996
# 18                           Alpena    MI     USA  45.0781  -83.5603
# 19                            Aspen    CO     USA  39.2232  -106.869
# 20                          Atlanta    GA     USA  33.6404  -84.4269
# 21                         Appleton    WI     USA  44.2574  -88.5195
# 22                           Austin    TX     USA  30.1945  -97.6699
# 23                        Asheville    NC     USA  35.4362  -82.5418
# 24            Wilkes-Barre/Scranton    PA     USA  41.3381  -75.7243
# 25                        Kalamazoo    MI     USA  42.2349  -85.5521
# 26                    Windsor Locks    CT     USA  41.9389  -72.6832
# 27                           Bethel    AK     USA  60.7798  -161.838
# 28                      Bakersfield    CA     USA  35.4336  -119.057
# 29                       Binghamton    NY     USA  42.2085  -75.9796
# ..                              ...   ...     ...      ...       ...
# 292                        Sarasota    FL     USA  27.3953  -82.5541
# 293                        St Cloud    MN     USA  45.5453  -94.0583
# 294                        St Louis    MO     USA  38.7477    -90.36
# 295                Charlotte Amalie    VI     USA  18.3373  -64.9734
# 296                   Christiansted    VI     USA  17.7019  -64.7986
# 297                          Hailey    ID     USA  43.5048  -114.297
# 298                      Sioux City    IA     USA  42.4026  -96.3844
# 299                        Newburgh    NY     USA  41.5041  -74.1048
# 300                        Syracuse    NY     USA  43.1112  -76.1063
# 301                     Tallahassee    FL     USA  30.3965  -84.3503
# 302                          Toledo    OH     USA  41.5868  -83.8078
# 303                           Tampa    FL     USA  27.9755  -82.5332
# 304                         Bristol    TN     USA  36.4752  -82.4074
# 305                         Trenton    NJ     USA  40.2767  -74.8135
# 306                           Tulsa    OK     USA  36.1984  -95.8882
# 307                          Tucson    AZ     USA  32.1161  -110.941
# 308                   Traverse City    MI     USA  44.7414  -85.5822
# 309                      Twin Falls    ID     USA  42.4818  -114.488
# 310                       Texarkana    AR     USA  33.4537   -93.991
# 311                           Tyler    TX     USA  32.3541  -95.4024
# 312                       Knoxville    TN     USA  35.8125  -83.9929
# 313                   St. Augustine    FL     USA      NaN       NaN
# 314                          Vernal    UT     USA  40.4409   -109.51
# 315                        Valdosta    GA     USA  30.7825  -83.2767
# 316                      Valparaiso    FL     USA  30.4833  -86.5254
# 317                        Wrangell    AK     USA  56.4843   -132.37
# 318                West Yellowstone    MT     USA  44.6884  -111.118
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.2819  -94.3068
# 320                         Yakutat    AK     USA  59.5034   -139.66
# 321                            Yuma    AZ     USA  32.6566  -114.606
#
# [322 rows x 7 columns]

# %%
airports.bfill()
# Out:
#     IATA_CODE                                            AIRPORT  \
# 0         ABE                Lehigh Valley International Airport
# 1         ABI                           Abilene Regional Airport
# 2         ABQ                  Albuquerque International Sunport
# 3         ABR                          Aberdeen Regional Airport
# 4         ABY                 Southwest Georgia Regional Airport
# 5         ACK                         Nantucket Memorial Airport
# 6         ACT                              Waco Regional Airport
# 7         ACV                                     Arcata Airport
# 8         ACY                Atlantic City International Airport
# 9         ADK                                       Adak Airport
# 10        ADQ                                     Kodiak Airport
# 11        AEX                   Alexandria International Airport
# 12        AGS              Augusta Regional Airport (Bush Field)
# 13        AKN                                King Salmon Airport
# 14        ALB                       Albany International Airport
# 15        ALO                          Waterloo Regional Airport
# 16        AMA        Rick Husband Amarillo International Airport
# 17        ANC        Ted Stevens Anchorage International Airport
# 18        APN                     Alpena County Regional Airport
# 19        ASE                        Aspen-Pitkin County Airport
# 20        ATL   Hartsfield-Jackson Atlanta International Airport
# 21        ATW                     Appleton International Airport
# 22        AUS             Austin-Bergstrom International Airport
# 23        AVL                         Asheville Regional Airport
# 24        AVP        Wilkes-Barre/Scranton International Airport
# 25        AZO       Kalamazoo/Battle Creek International Airport
# 26        BDL                      Bradley International Airport
# 27        BET                                     Bethel Airport
# 28        BFL                                      Meadows Field
# 29        BGM                         Greater Binghamton Airport
# ..        ...                                                ...
# 292       SRQ           Sarasota-Bradenton International Airport
# 293       STC                         St. Cloud Regional Airport
# 294       STL   St. Louis International Airport at Lambert Field
# 295       STT                              Cyril E. King Airport
# 296       STX                           Henry E. Rohlsen Airport
# 297       SUN                          Friedman Memorial Airport
# 298       SUX                              Sioux Gateway Airport
# 299       SWF                      Stewart International Airport
# 300       SYR             Syracuse Hancock International Airport
# 301       TLH                  Tallahassee International Airport
# 302       TOL                             Toledo Express Airport
# 303       TPA                        Tampa International Airport
# 304       TRI                        Tri-Cities Regional Airport
# 305       TTN                             Trenton Mercer Airport
# 306       TUL                        Tulsa International Airport
# 307       TUS                       Tucson International Airport
# 308       TVC                             Cherry Capital Airport
# 309       TWF       Magic Valley Regional Airport (Joslin Field)
# 310       TXK            Texarkana Regional Airport (Webb Field)
# 311       TYR                      Tyler Pounds Regional Airport
# 312       TYS                               McGhee Tyson Airport
# 313       UST  Northeast Florida Regional Airport (St. August...
# 314       VEL                                     Valdez Airport
# 315       VLD                          Valdosta Regional Airport
# 316       VPS         Destin-Fort Walton Beach Airport/Eglin AFB
# 317       WRG                                   Wrangell Airport
# 318       WYS                             Westerly State Airport
# 319       XNA                Northwest Arkansas Regional Airport
# 320       YAK                                    Yakutat Airport
# 321       YUM                         Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# 5                         Nantucket    MA     USA  41.25305  -70.06018
# 6                              Waco    TX     USA  31.61129  -97.23052
# 7                     Arcata/Eureka    CA     USA  40.97812 -124.10862
# 8                     Atlantic City    NJ     USA  39.45758  -74.57717
# 9                              Adak    AK     USA  51.87796 -176.64603
# 10                           Kodiak    AK     USA  57.74997 -152.49386
# 11                       Alexandria    LA     USA  31.32737  -92.54856
# 12                          Augusta    GA     USA  33.36996  -81.96450
# 13                      King Salmon    AK     USA  58.67680 -156.64922
# 14                           Albany    NY     USA  42.74812  -73.80298
# 15                         Waterloo    IA     USA  42.55708  -92.40034
# 16                         Amarillo    TX     USA  35.21937 -101.70593
# 17                        Anchorage    AK     USA  61.17432 -149.99619
# 18                           Alpena    MI     USA  45.07807  -83.56029
# 19                            Aspen    CO     USA  39.22316 -106.86885
# 20                          Atlanta    GA     USA  33.64044  -84.42694
# 21                         Appleton    WI     USA  44.25741  -88.51948
# 22                           Austin    TX     USA  30.19453  -97.66987
# 23                        Asheville    NC     USA  35.43619  -82.54181
# 24            Wilkes-Barre/Scranton    PA     USA  41.33815  -75.72427
# 25                        Kalamazoo    MI     USA  42.23488  -85.55206
# 26                    Windsor Locks    CT     USA  41.93887  -72.68323
# 27                           Bethel    AK     USA  60.77978 -161.83800
# 28                      Bakersfield    CA     USA  35.43360 -119.05677
# 29                       Binghamton    NY     USA  42.20848  -75.97961
# ..                              ...   ...     ...       ...        ...
# 292                        Sarasota    FL     USA  27.39533  -82.55411
# 293                        St Cloud    MN     USA  45.54532  -94.05834
# 294                        St Louis    MO     USA  38.74769  -90.35999
# 295                Charlotte Amalie    VI     USA  18.33731  -64.97336
# 296                   Christiansted    VI     USA  17.70189  -64.79856
# 297                          Hailey    ID     USA  43.50484 -114.29659
# 298                      Sioux City    IA     USA  42.40260  -96.38437
# 299                        Newburgh    NY     USA  41.50409  -74.10484
# 300                        Syracuse    NY     USA  43.11119  -76.10631
# 301                     Tallahassee    FL     USA  30.39653  -84.35033
# 302                          Toledo    OH     USA  41.58681  -83.80783
# 303                           Tampa    FL     USA  27.97547  -82.53325
# 304                         Bristol    TN     USA  36.47521  -82.40742
# 305                         Trenton    NJ     USA  40.27669  -74.81347
# 306                           Tulsa    OK     USA  36.19837  -95.88824
# 307                          Tucson    AZ     USA  32.11608 -110.94103
# 308                   Traverse City    MI     USA  44.74144  -85.58224
# 309                      Twin Falls    ID     USA  42.48180 -114.48774
# 310                       Texarkana    AR     USA  33.45371  -93.99102
# 311                           Tyler    TX     USA  32.35414  -95.40239
# 312                       Knoxville    TN     USA  35.81249  -83.99286
# 313                   St. Augustine    FL     USA  40.44090 -109.50992
# 314                          Vernal    UT     USA  40.44090 -109.50992
# 315                        Valdosta    GA     USA  30.78250  -83.27672
# 316                      Valparaiso    FL     USA  30.48325  -86.52540
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
airports.cummax()
# Out:
#     IATA_CODE                                      AIRPORT  \
# 0         ABE          Lehigh Valley International Airport
# 1         ABI          Lehigh Valley International Airport
# 2         ABQ          Lehigh Valley International Airport
# 3         ABR          Lehigh Valley International Airport
# 4         ABY           Southwest Georgia Regional Airport
# 5         ACK           Southwest Georgia Regional Airport
# 6         ACT                        Waco Regional Airport
# 7         ACV                        Waco Regional Airport
# 8         ACY                        Waco Regional Airport
# 9         ADK                        Waco Regional Airport
# 10        ADQ                        Waco Regional Airport
# 11        AEX                        Waco Regional Airport
# 12        AGS                        Waco Regional Airport
# 13        AKN                        Waco Regional Airport
# 14        ALB                        Waco Regional Airport
# 15        ALO                    Waterloo Regional Airport
# 16        AMA                    Waterloo Regional Airport
# 17        ANC                    Waterloo Regional Airport
# 18        APN                    Waterloo Regional Airport
# 19        ASE                    Waterloo Regional Airport
# 20        ATL                    Waterloo Regional Airport
# 21        ATW                    Waterloo Regional Airport
# 22        AUS                    Waterloo Regional Airport
# 23        AVL                    Waterloo Regional Airport
# 24        AVP  Wilkes-Barre/Scranton International Airport
# 25        AZO  Wilkes-Barre/Scranton International Airport
# 26        BDL  Wilkes-Barre/Scranton International Airport
# 27        BET  Wilkes-Barre/Scranton International Airport
# 28        BFL  Wilkes-Barre/Scranton International Airport
# 29        BGM  Wilkes-Barre/Scranton International Airport
# ..        ...                                          ...
# 292       SRQ                 Yellowstone Regional Airport
# 293       STC                 Yellowstone Regional Airport
# 294       STL                 Yellowstone Regional Airport
# 295       STT                 Yellowstone Regional Airport
# 296       STX                 Yellowstone Regional Airport
# 297       SUN                 Yellowstone Regional Airport
# 298       SUX                 Yellowstone Regional Airport
# 299       SWF                 Yellowstone Regional Airport
# 300       SYR                 Yellowstone Regional Airport
# 301       TLH                 Yellowstone Regional Airport
# 302       TOL                 Yellowstone Regional Airport
# 303       TPA                 Yellowstone Regional Airport
# 304       TRI                 Yellowstone Regional Airport
# 305       TTN                 Yellowstone Regional Airport
# 306       TUL                 Yellowstone Regional Airport
# 307       TUS                 Yellowstone Regional Airport
# 308       TVC                 Yellowstone Regional Airport
# 309       TWF                 Yellowstone Regional Airport
# 310       TXK                 Yellowstone Regional Airport
# 311       TYR                 Yellowstone Regional Airport
# 312       TYS                 Yellowstone Regional Airport
# 313       UST                 Yellowstone Regional Airport
# 314       VEL                 Yellowstone Regional Airport
# 315       VLD                 Yellowstone Regional Airport
# 316       VPS                 Yellowstone Regional Airport
# 317       WRG                 Yellowstone Regional Airport
# 318       WYS                 Yellowstone Regional Airport
# 319       XNA                 Yellowstone Regional Airport
# 320       YAK                 Yellowstone Regional Airport
# 321       YUM                   Yuma International Airport
#
#                       CITY STATE COUNTRY LATITUDE LONGITUDE
# 0                Allentown    PA     USA  40.6524  -75.4404
# 1                Allentown    TX     USA  40.6524  -75.4404
# 2                Allentown    TX     USA  40.6524  -75.4404
# 3                Allentown    TX     USA  45.4491  -75.4404
# 4                Allentown    TX     USA  45.4491  -75.4404
# 5                Nantucket    TX     USA  45.4491  -70.0602
# 6                     Waco    TX     USA  45.4491  -70.0602
# 7                     Waco    TX     USA  45.4491  -70.0602
# 8                     Waco    TX     USA  45.4491  -70.0602
# 9                     Waco    TX     USA   51.878  -70.0602
# 10                    Waco    TX     USA    57.75  -70.0602
# 11                    Waco    TX     USA    57.75  -70.0602
# 12                    Waco    TX     USA    57.75  -70.0602
# 13                    Waco    TX     USA  58.6768  -70.0602
# 14                    Waco    TX     USA  58.6768  -70.0602
# 15                Waterloo    TX     USA  58.6768  -70.0602
# 16                Waterloo    TX     USA  58.6768  -70.0602
# 17                Waterloo    TX     USA  61.1743  -70.0602
# 18                Waterloo    TX     USA  61.1743  -70.0602
# 19                Waterloo    TX     USA  61.1743  -70.0602
# 20                Waterloo    TX     USA  61.1743  -70.0602
# 21                Waterloo    WI     USA  61.1743  -70.0602
# 22                Waterloo    WI     USA  61.1743  -70.0602
# 23                Waterloo    WI     USA  61.1743  -70.0602
# 24   Wilkes-Barre/Scranton    WI     USA  61.1743  -70.0602
# 25   Wilkes-Barre/Scranton    WI     USA  61.1743  -70.0602
# 26           Windsor Locks    WI     USA  61.1743  -70.0602
# 27           Windsor Locks    WI     USA  61.1743  -70.0602
# 28           Windsor Locks    WI     USA  61.1743  -70.0602
# 29           Windsor Locks    WI     USA  61.1743  -70.0602
# ..                     ...   ...     ...      ...       ...
# 292              Worcester    WY     USA  71.2854  -66.0018
# 293              Worcester    WY     USA  71.2854  -66.0018
# 294              Worcester    WY     USA  71.2854  -66.0018
# 295              Worcester    WY     USA  71.2854  -64.9734
# 296              Worcester    WY     USA  71.2854  -64.7986
# 297              Worcester    WY     USA  71.2854  -64.7986
# 298              Worcester    WY     USA  71.2854  -64.7986
# 299              Worcester    WY     USA  71.2854  -64.7986
# 300              Worcester    WY     USA  71.2854  -64.7986
# 301              Worcester    WY     USA  71.2854  -64.7986
# 302              Worcester    WY     USA  71.2854  -64.7986
# 303              Worcester    WY     USA  71.2854  -64.7986
# 304              Worcester    WY     USA  71.2854  -64.7986
# 305              Worcester    WY     USA  71.2854  -64.7986
# 306              Worcester    WY     USA  71.2854  -64.7986
# 307              Worcester    WY     USA  71.2854  -64.7986
# 308              Worcester    WY     USA  71.2854  -64.7986
# 309              Worcester    WY     USA  71.2854  -64.7986
# 310              Worcester    WY     USA  71.2854  -64.7986
# 311              Worcester    WY     USA  71.2854  -64.7986
# 312              Worcester    WY     USA  71.2854  -64.7986
# 313              Worcester    WY     USA      NaN       NaN
# 314              Worcester    WY     USA  71.2854  -64.7986
# 315              Worcester    WY     USA  71.2854  -64.7986
# 316              Worcester    WY     USA  71.2854  -64.7986
# 317               Wrangell    WY     USA  71.2854  -64.7986
# 318               Wrangell    WY     USA  71.2854  -64.7986
# 319               Wrangell    WY     USA  71.2854  -64.7986
# 320                Yakutat    WY     USA  71.2854  -64.7986
# 321                   Yuma    WY     USA  71.2854  -64.7986
#
# [322 rows x 7 columns]

# %%
airports.isna()
# Out:
#      IATA_CODE  AIRPORT   CITY  STATE  COUNTRY  LATITUDE  LONGITUDE
# 0        False    False  False  False    False     False      False
# 1        False    False  False  False    False     False      False
# 2        False    False  False  False    False     False      False
# 3        False    False  False  False    False     False      False
# 4        False    False  False  False    False     False      False
# 5        False    False  False  False    False     False      False
# 6        False    False  False  False    False     False      False
# 7        False    False  False  False    False     False      False
# 8        False    False  False  False    False     False      False
# 9        False    False  False  False    False     False      False
# 10       False    False  False  False    False     False      False
# 11       False    False  False  False    False     False      False
# 12       False    False  False  False    False     False      False
# 13       False    False  False  False    False     False      False
# 14       False    False  False  False    False     False      False
# 15       False    False  False  False    False     False      False
# 16       False    False  False  False    False     False      False
# 17       False    False  False  False    False     False      False
# 18       False    False  False  False    False     False      False
# 19       False    False  False  False    False     False      False
# 20       False    False  False  False    False     False      False
# 21       False    False  False  False    False     False      False
# 22       False    False  False  False    False     False      False
# 23       False    False  False  False    False     False      False
# 24       False    False  False  False    False     False      False
# 25       False    False  False  False    False     False      False
# 26       False    False  False  False    False     False      False
# 27       False    False  False  False    False     False      False
# 28       False    False  False  False    False     False      False
# 29       False    False  False  False    False     False      False
# ..         ...      ...    ...    ...      ...       ...        ...
# 292      False    False  False  False    False     False      False
# 293      False    False  False  False    False     False      False
# 294      False    False  False  False    False     False      False
# 295      False    False  False  False    False     False      False
# 296      False    False  False  False    False     False      False
# 297      False    False  False  False    False     False      False
# 298      False    False  False  False    False     False      False
# 299      False    False  False  False    False     False      False
# 300      False    False  False  False    False     False      False
# 301      False    False  False  False    False     False      False
# 302      False    False  False  False    False     False      False
# 303      False    False  False  False    False     False      False
# 304      False    False  False  False    False     False      False
# 305      False    False  False  False    False     False      False
# 306      False    False  False  False    False     False      False
# 307      False    False  False  False    False     False      False
# 308      False    False  False  False    False     False      False
# 309      False    False  False  False    False     False      False
# 310      False    False  False  False    False     False      False
# 311      False    False  False  False    False     False      False
# 312      False    False  False  False    False     False      False
# 313      False    False  False  False    False      True       True
# 314      False    False  False  False    False     False      False
# 315      False    False  False  False    False     False      False
# 316      False    False  False  False    False     False      False
# 317      False    False  False  False    False     False      False
# 318      False    False  False  False    False     False      False
# 319      False    False  False  False    False     False      False
# 320      False    False  False  False    False     False      False
# 321      False    False  False  False    False     False      False
#
# [322 rows x 7 columns]

# %% [markdown]
# ### Quick knowledge check:

# %% [markdown]
# - Where can you find the list of available attributes and methods for a pre-created class?

# %% [markdown]
# - what's the key difference between an attribute and a method?

# %% [markdown]
# - What is the appropriate sequence of these words?  A variable becomes an _______ when you _______ a _______ .
#  - A: Initialize
#  - B: Class
#  - C: Object

# %% [markdown]
# ### So creating a _class_ is essentially creating a _blueprint_ for how you want to store and manipulate data.
#
# ![blueprint](img/blueprint.jpeg)

# %% [markdown]
# ### Let's start by making a car `class` and giving it some `attributes`

# %%
class Car():
    pass

# %%
ferrari = Car()
lambo = Car()

# %% [markdown]
# #### Check the class of lambo

# %%
type(lambo)
# Out:
# __main__.Car

# %% [markdown]
# #### Can assign attributes to a class object after it's been defined and intitialized

# %%
ferrari.max_speed = 200
ferrari.max_speed
# Out:
# 200

# %% [markdown]
# #### But what if we try to return the `max_speed` of lambo?

# %%
lambo.max_speed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-23a8731a26d4> in <module>()
# ----> 1 lambo.max_speed
#
# AttributeError: 'Car' object has no attribute 'max_speed'

# %% [markdown]
# #### Let's update our car class so it has more attributes

# %%
class Car():
    wheels = 4

# %%
ford = Car()
ford.wheels
# Out:
# 4

# %% [markdown]
# #### What if we wanted to set some parameters when we initialize the object?

# %%
class Car():
    wheels = 4
    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type

# %%
lambo = Car(200, 'sport')

# %% [markdown]
# #### Confirm our assignment worked

# %%
print(lambo.wheels)
print(lambo.max_speed)
print(lambo.c_type)
# Out:
# 4
# 200
# sport

# %% [markdown]
# #### What if you try to initialize it without one of the terms?

# %%
test = Car(55)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-4d3a40aca94d> in <module>()
# ----> 1 test = Car(55)
#
# TypeError: __init__() missing 1 required positional argument: 'c_type'

# %% [markdown]
# ## Now let's create a method for our car class

# %%
class Car():
    wheels = 4
    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type
    def go(self):
        print('going')
        self.moving = True

# %%
prius = Car(100, 'slow')
prius.go()
# Out:
# going

# %% [markdown]
# #### **Task** create another method for car `stop`
#
# - stop should print 'stopped'
# - stop should set the attribute `moving` to `False`

# %%
class Car():
    wheels = 4
    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type
    def go(self):
        print('going')
        self.moving = True
    def stop(self):
        self.moving = False
        print('stopped')

# %%
prius = Car(100, 'slow')
prius.stop()
# Out:
# stopped

# %% [markdown]
# **Task**: Make a pizza class<br>
#
# - Pizza should take one topping and the size of the pizza when instantiated
# - Pizza should have an attribute `toppings` that stores toppings in a list
# - Pizza should have methods `.add_topping`, `print_toppings`, and `remove_topping`

# %%
class Pizza:
        def __init__(self, first_topping, size):
            self.first_topping = first_topping
            self.size = size
            self.toppings = [self.first_topping]
        def add_topping(self, another_topping):
            self.another_topping = another_topping
            self.toppings.append(self.another_topping)
        def remove_topping(self, del_topping):
            self.del_topping = del_topping
            self.toppings.remove(self.del_topping)
        def print_topping(self):
            print(self.toppings)

# %%
pie = Pizza('cheese', 'small')

# %%
pie.add_topping('olive')
pie.add_topping('tomato')
pie.print_topping()
# Out:
# ['cheese', 'olive', 'tomato']

# %%
pie.remove_topping('olive')
pie.print_topping()
# Out:
# ['cheese', 'tomato']

# %% [markdown]
# **Extra Credit**
#
# - Pizza should have an attribute "order_status" that starts as equaling `none`. order_status should change depending on the methods:
#  - `done_adjusting_order`
#  - `preparing`
#  - `delivering`
#  - `delivered`
# - order_status, when called, should return in the form of a sentence.

# %% [markdown]
# ### Integration
# Make a plan for a stock class
#
# - What would you want it to take when instantiated?
# - what methods would you want it to have?
# - for predicting, would you want it to default to one modeling technique? or would you be able to specify?
# - What input data would it take?
# - What attributes would you want to be able to reference?

# %% [markdown]
# ## Assessment:
#
# ![greg](img/thinking.jpeg)
#
# It's Greg again. <br>
# You overhear him talking to his peers about how OOB is irrelevant to the data science skill set. <br>
# When Greg meets with you for his one-on-one, how would you correct him?

# %% [markdown]
# ## Reflection
#
# ![traffic](img/stoplight.jpeg)
#
# - One item you feel green -  ready to go on
# - One item you feel yellow - kind of get but not quite
# - One item you feel red - absolutely do not get

# %% [markdown]
# ## Part 2 - The simulation lab from learn.co
# Later today.
